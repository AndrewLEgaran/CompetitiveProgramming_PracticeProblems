# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewLEgaran/CompetitiveProgramming_PracticeProblems/blob/main/Rosal_Survey_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

url = "https://raw.githubusercontent.com/AndrewLEgaran/Final-Project-CS2/refs/heads/main/data/survey.json"
response = requests.get(url)
survey = response.json()

print(survey)
# Out:
# [{'respondent_id': 1, 'age': 16, 'gender': 'Female', 'grade_level': 'Grade 11', 'section': 'STEM-A', 'q1_satisfaction': 4, 'q2_usability': 5, 'q3_design': 4, 'q4_clarity': 5, 'q5_recommend': 5, 'q6_overall': 5, 'q7_comments': 'Very helpful and easy to use. I’d recommend it to friends.'}, {'respondent_id': 2, 'age': 17, 'gender': 'Male', 'grade_level': 'Grade 12', 'section': 'ABM-B', 'q1_satisfaction': 3, 'q2_usability': 3, 'q3_design': 3, 'q4_clarity': 4, 'q5_recommend': 3, 'q6_overall': 3, 'q7_comments': 'It’s okay but could be improved in terms of navigation.'}, {'respondent_id': 3, 'age': 16, 'gender': 'Female', 'grade_level': 'Grade 11', 'section': 'STEM-C', 'q1_satisfaction': 5, 'q2_usability': 4, 'q3_design': 5, 'q4_clarity': 5, 'q5_recommend': 5, 'q6_overall': 5, 'q7_comments': 'I really liked the experience! It was engaging.'}, {'respondent_id': 4, 'age': 15, 'gender': 'Male', 'grade_level': 'Grade 10', 'section': 'GAS-A', 'q1_satisfaction': 2, 'q2_usability': 3, 'q3_design': 2, 'q4_clarity': 3, 'q5_recommend': 2, 'q6_overall': 2, 'q7_comments': 'Some parts were confusing. Needs clearer instructions.'}, {'respondent_id': 5, 'age': 18, 'gender': 'Female', 'grade_level': 'Grade 12', 'section': 'HUMSS-B', 'q1_satisfaction': 4, 'q2_usability': 4, 'q3_design': 5, 'q4_clarity': 4, 'q5_recommend': 5, 'q6_overall': 4, 'q7_comments': 'Good balance of design and usability. Pretty solid.'}, {'respondent_id': 6, 'age': 17, 'gender': 'Male', 'grade_level': 'Grade 11', 'section': 'STEM-B', 'q1_satisfaction': 5, 'q2_usability': 5, 'q3_design': 4, 'q4_clarity': 5, 'q5_recommend': 5, 'q6_overall': 5, 'q7_comments': 'Really smooth and enjoyable to use!'}, {'respondent_id': 7, 'age': 16, 'gender': 'Female', 'grade_level': 'Grade 10', 'section': 'ABM-A', 'q1_satisfaction': 3, 'q2_usability': 2, 'q3_design': 3, 'q4_clarity': 3, 'q5_recommend': 2, 'q6_overall': 3, 'q7_comments': 'The layout is fine but loading speed should be faster.'}, {'respondent_id': 8, 'age': 17, 'gender': 'Male', 'grade_level': 'Grade 12', 'section': 'TVL-A', 'q1_satisfaction': 4, 'q2_usability': 4, 'q3_design': 4, 'q4_clarity': 4, 'q5_recommend': 4, 'q6_overall': 4, 'q7_comments': 'Consistent performance. Works well on mobile.'}, {'respondent_id': 9, 'age': 15, 'gender': 'Female', 'grade_level': 'Grade 9', 'section': 'STEM-D', 'q1_satisfaction': 2, 'q2_usability': 2, 'q3_design': 2, 'q4_clarity': 2, 'q5_recommend': 1, 'q6_overall': 2, 'q7_comments': 'I had trouble figuring out some features. Needs improvement.'}, {'respondent_id': 10, 'age': 18, 'gender': 'Male', 'grade_level': 'Grade 12', 'section': 'HUMSS-A', 'q1_satisfaction': 5, 'q2_usability': 5, 'q3_design': 5, 'q4_clarity': 5, 'q5_recommend': 5, 'q6_overall': 5, 'q7_comments': 'Perfect! Everything worked just as expected.'}]

# %%
# !pip install firebase-admin
# Out:
# Requirement already satisfied: firebase-admin in /usr/local/lib/python3.12/dist-packages (6.9.0)
# Requirement already satisfied: cachecontrol>=0.12.14 in /usr/local/lib/python3.12/dist-packages (from firebase-admin) (0.14.4)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.12/dist-packages (from firebase-admin) (2.192.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /usr/local/lib/python3.12/dist-packages (from firebase-admin) (3.9.0)
# Requirement already satisfied: pyjwt>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (2.11.0)
# Requirement already satisfied: httpx==0.28.1 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]==0.28.1->firebase-admin) (0.28.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.30.0)
# Requirement already satisfied: google-cloud-firestore>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from firebase-admin) (2.24.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (3.11)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]==0.28.1->firebase-admin) (4.3.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (0.16.0)
# Requirement already satisfied: requests>=2.16.0 in /usr/local/lib/python3.12/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (2.32.4)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.12/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (1.1.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.27.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.47.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.78.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.71.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.3.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.2.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-firestore>=2.19.0->firebase-admin) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (1.8.0)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9.1)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.15.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin) (4.1.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.2)

# %%
import firebase_admin
from firebase_admin import credentials, db
# Load the private key
cred = credentials.Certificate("/content/firebaserose.json")
# Initialize the app with your database URL
if not firebase_admin._apps:
  firebase_admin.initialize_app(cred, {
    "databaseURL": "https://rosal-survey-db-default-rtdb.asia-southeast1.firebasedatabase.app/"
  })
  print("Firebase connected successfully!")
else:
  print("Firebase already initialized")
# Out:
# Firebase connected successfully!

# %%
import requests
import json

data = survey
print("JSON file loaded")
ref = db.reference("survey")

for student in data:
  ref.child(str(student["respondent_id"])).set(student)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
survey_ref = db.reference("survey")
survey_data = survey_ref.get()
print(survey_data)
# Out:
# [None, {'age': 16, 'gender': 'Female', 'grade_level': 'Grade 11', 'q1_satisfaction': 4, 'q2_usability': 5, 'q3_design': 4, 'q4_clarity': 5, 'q5_recommend': 5, 'q6_overall': 5, 'q7_comments': 'Very helpful and easy to use. I’d recommend it to friends.', 'respondent_id': 1, 'section': 'STEM-A'}, {'age': 17, 'gender': 'Male', 'grade_level': 'Grade 12', 'q1_satisfaction': 3, 'q2_usability': 3, 'q3_design': 3, 'q4_clarity': 4, 'q5_recommend': 3, 'q6_overall': 3, 'q7_comments': 'It’s okay but could be improved in terms of navigation.', 'respondent_id': 2, 'section': 'ABM-B'}, {'age': 16, 'gender': 'Female', 'grade_level': 'Grade 11', 'q1_satisfaction': 5, 'q2_usability': 4, 'q3_design': 5, 'q4_clarity': 5, 'q5_recommend': 5, 'q6_overall': 5, 'q7_comments': 'I really liked the experience! It was engaging.', 'respondent_id': 3, 'section': 'STEM-C'}, {'age': 15, 'gender': 'Male', 'grade_level': 'Grade 10', 'q1_satisfaction': 2, 'q2_usability': 3, 'q3_design': 2, 'q4_clarity': 3, 'q5_recommend': 2, 'q6_overall': 2, 'q7_comments': 'Some parts were confusing. Needs clearer instructions.', 'respondent_id': 4, 'section': 'GAS-A'}, {'age': 18, 'gender': 'Female', 'grade_level': 'Grade 12', 'q1_satisfaction': 4, 'q2_usability': 4, 'q3_design': 5, 'q4_clarity': 4, 'q5_recommend': 5, 'q6_overall': 4, 'q7_comments': 'Good balance of design and usability. Pretty solid.', 'respondent_id': 5, 'section': 'HUMSS-B'}, {'age': 17, 'gender': 'Male', 'grade_level': 'Grade 11', 'q1_satisfaction': 5, 'q2_usability': 5, 'q3_design': 4, 'q4_clarity': 5, 'q5_recommend': 5, 'q6_overall': 5, 'q7_comments': 'Really smooth and enjoyable to use!', 'respondent_id': 6, 'section': 'STEM-B'}, {'age': 16, 'gender': 'Female', 'grade_level': 'Grade 10', 'q1_satisfaction': 3, 'q2_usability': 2, 'q3_design': 3, 'q4_clarity': 3, 'q5_recommend': 2, 'q6_overall': 3, 'q7_comments': 'The layout is fine but loading speed should be faster.', 'respondent_id': 7, 'section': 'ABM-A'}, {'age': 17, 'gender': 'Male', 'grade_level': 'Grade 12', 'q1_satisfaction': 4, 'q2_usability': 4, 'q3_design': 4, 'q4_clarity': 4, 'q5_recommend': 4, 'q6_overall': 4, 'q7_comments': 'Consistent performance. Works well on mobile.', 'respondent_id': 8, 'section': 'TVL-A'}, {'age': 15, 'gender': 'Female', 'grade_level': 'Grade 9', 'q1_satisfaction': 2, 'q2_usability': 2, 'q3_design': 2, 'q4_clarity': 2, 'q5_recommend': 1, 'q6_overall': 2, 'q7_comments': 'I had trouble figuring out some features. Needs improvement.', 'respondent_id': 9, 'section': 'STEM-D'}, {'age': 18, 'gender': 'Male', 'grade_level': 'Grade 12', 'q1_satisfaction': 5, 'q2_usability': 5, 'q3_design': 5, 'q4_clarity': 5, 'q5_recommend': 5, 'q6_overall': 5, 'q7_comments': 'Perfect! Everything worked just as expected.', 'respondent_id': 10, 'section': 'HUMSS-A'}]

# %%
ref = db.reference("survey")

while True:
  print("\n===== Showtime Survey Menu! =====")
  print("1. Showtime!") #Display
  print("2. Contestant Applications!") #Add new survey data

  Decision = input("Please Enter Your Decision: ")

  # Showtime | Display
  if Decision == "1":
    survey_data_from_db = ref.get()
    print("\nStudent List: ")
    # Iterate through the list, skipping None entries (Firebase returns list with None at index 0 if keys are sequential integers)
    for survey_item in survey_data_from_db:
      if survey_item is not None:
        print(f"ID: {survey_item['respondent_id']}, Age: {survey_item['age']}, Gender: {survey_item['gender']}, Grade_Level: {survey_item['grade_level']}, Satisfaction: {survey_item['q1_satisfaction']}, Usability: {survey_item['q2_usability']}, Design: {survey_item['q3_design']}, Clarity: {survey_item['q4_clarity']}, Suggest: {survey_item['q5_recommend']}, Overall: {survey_item['q6_overall']}, Feedback: {survey_item['q7_comments']}, Faction: {survey_item['section']} ")

  #Contestant Applications! | Add new survey data
  elif Decision == "2":
    NewID = input("Enter Applicant ID: ")
    AgeVerification = input("Enter Applicant Age: ")
    GenderIdentity = input("Enter Applicant Gender: ")
    GradeIQ = input("Enter Applicant Grade Level: ")
    Satisfaction = input("Enter Satisfaction Rating (1-5): ")
    Usability = input("Enter Usability Rating (1-5): ")
    Design = input("Enter Design Rating (1-5): ")
    Clarity = input("Enter Clarity Rating (1-5): ")
    Suggest = input("Enter Recommendation Rating (1-5): ")
    Overall = input("Enter Overall Rating (1-5): ")
    Feedback = input("Enter Applicant's Commentations: ")
    Faction = input("Enter Applicant's Section: ")

    survey = {
        "respondent_id": int(NewID),
        "age": int(AgeVerification),
        "gender": GenderIdentity,
        "grade_level": GradeIQ,
        "q1_satisfaction": int(Satisfaction),
        "q2_usability": int(Usability),
        "q3_design": int(Design),
        "q4_clarity": int(Clarity),
        "q5_recommend": int(Suggest),
        "q6_overall": int(Overall),
        "q7_comments": Feedback,
        "section": Faction

    }
    ref.child(str(NewID)).set(survey)
    print("Data uploaded successfully!")

  #Grand Finale | Exit
  elif Decision == "5":
    print("Thank you for using the Showtime Survey Menu!")
    break

  #Error 404
  else:
    print("Error 400, Please try again...")
# Out:
# ===== Showtime Survey Menu! =====
# 1. Showtime!
# 2. Contestant Applications!
# Please Enter Your Decision: 5
# Thank you for using the Showtime Survey Menu!

# %%
respondent_avg_scores = []
question_keys = ['q1_satisfaction', 'q2_usability', 'q3_design', 'q4_clarity', 'q5_recommend', 'q6_overall']

for respondent in survey_data:
    if respondent is not None:
        scores_for_respondent = []
        for q_key in question_keys:
            if q_key in respondent and isinstance(respondent[q_key], (int, float)):
                scores_for_respondent.append(respondent[q_key])

        if scores_for_respondent:
            average_for_respondent = sum(scores_for_respondent) / len(scores_for_respondent)
            respondent_avg_scores.append({
                'respondent_id': respondent.get('respondent_id', 'N/A'),
                'average_score_q1_q6': f"{average_for_respondent:.2f}"
            })

print("Average Scores for each Respondent (Q1-Q6):")
for avg_score_data in respondent_avg_scores:
    print(f"  Respondent ID: {avg_score_data['respondent_id']}, Average Score: {avg_score_data['average_score_q1_q6']}")
# Out:
# Average Scores for each Respondent (Q1-Q6):
#   Respondent ID: 1, Average Score: 4.67
#   Respondent ID: 2, Average Score: 3.17
#   Respondent ID: 3, Average Score: 4.83
#   Respondent ID: 4, Average Score: 2.33
#   Respondent ID: 5, Average Score: 4.33
#   Respondent ID: 6, Average Score: 4.83
#   Respondent ID: 7, Average Score: 2.67
#   Respondent ID: 8, Average Score: 4.00
#   Respondent ID: 9, Average Score: 1.83
#   Respondent ID: 10, Average Score: 5.00
